# %% [markdown]
# ### Phik-matrix -> Associations

# %% [markdown]
# Associations measure the strength of assocation between two variables. While correlations only measure LINEAR connection, associations can also handle non-linear connections. See "associations_vs_correlations.ipynb" for a simple comparison where associations are usually more useful.

# %% [markdown]
# **NOTE!** You can see both the correlations and associations at the asme time if you use SweetViz or Dython! You can also have correlations/phik-matrix in ydata at the same time, if you configure it correctly.

# %%
# if phik-matrix not found in pandas, try:
# pip install phik
import phik
import pandas as pd

# load data
df = pd.read_csv("../houses_fixed.csv")

# compute phik-matrix values
phik_matrix = df.phik_matrix()

phik_matrix
# Out:
# interval columns not set, guessing: ['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
#                      id      date     price  bedrooms  bathrooms  sqft_living  \
# id             1.000000  0.057917  0.071922  0.042775   0.079523     0.079736
# date           0.057917  1.000000  0.000000  0.000000   0.218503     0.000000
# price          0.071922  0.000000  1.000000  0.295426   0.741976     0.897678
# bedrooms       0.042775  0.000000  0.295426  1.000000   0.513440     0.577934
# bathrooms      0.079523  0.218503  0.741976  0.513440   1.000000     0.872038
# sqft_living    0.079736  0.000000  0.897678  0.577934   0.872038     1.000000
# sqft_lot       0.083328  0.117694  0.039998  0.000000   0.078175     0.099387
# floors         0.080466  0.000000  0.206170  0.206289   0.467907     0.361306
# ...

# %% [markdown]
# Correlations for comparison

# %%
# you can compare to correlations too
df.corr(numeric_only=True)
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...
