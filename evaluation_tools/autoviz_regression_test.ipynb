# %% [markdown]
# ### Generate data quality suggestions with AutoViz

# %%
# pip install autoviz
# pip install jinja2==3.1.2
# pip install jupyter_bokeh
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()
report = AV.AutoViz("houses.csv")
# Out:
# Imported v0.1.905. Please call AutoViz in this sequence:
#     AV = AutoViz_Class()
#     %matplotlib inline
#     dfte = AV.AutoViz(filename, sep=',', depVar='', dfte=None, header=0, verbose=1, lowess=False,
#                chart_format='svg',max_rows_analyzed=150000,max_cols_analyzed=30, save_plot_dir=None)
# Shape of your Data Set loaded: (21613, 21)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  5
#     Number of Integer-Categorical Columns =  13
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     21 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
#     All variables classified into correct types.
# <style type="text/css">
# #T_6c4c4_row0_col0, #T_6c4c4_row0_col2, #T_6c4c4_row0_col3, #T_6c4c4_row0_col4, #T_6c4c4_row0_col5, #T_6c4c4_row1_col0, #T_6c4c4_row1_col2, #T_6c4c4_row1_col3, #T_6c4c4_row1_col4, #T_6c4c4_row1_col5, #T_6c4c4_row2_col0, #T_6c4c4_row2_col2, #T_6c4c4_row2_col3, #T_6c4c4_row2_col4, #T_6c4c4_row2_col5, #T_6c4c4_row3_col0, #T_6c4c4_row3_col2, #T_6c4c4_row3_col3, #T_6c4c4_row3_col4, #T_6c4c4_row3_col5, #T_6c4c4_row4_col0, #T_6c4c4_row4_col2, #T_6c4c4_row4_col3, #T_6c4c4_row4_col4, #T_6c4c4_row4_col5, #T_6c4c4_row5_col0, #T_6c4c4_row5_col2, #T_6c4c4_row5_col3, #T_6c4c4_row5_col4, #T_6c4c4_row5_col5, #T_6c4c4_row6_col0, #T_6c4c4_row6_col2, #T_6c4c4_row6_col3, #T_6c4c4_row6_col4, #T_6c4c4_row6_col5, #T_6c4c4_row7_col0, #T_6c4c4_row7_col2, #T_6c4c4_row7_col3, #T_6c4c4_row7_col4, #T_6c4c4_row7_col5, #T_6c4c4_row8_col0, #T_6c4c4_row8_col2, #T_6c4c4_row8_col3, #T_6c4c4_row8_col4, #T_6c4c4_row8_col5, #T_6c4c4_row9_col0, #T_6c4c4_row9_col2, #T_6c4c4_row9_col3, #T_6c4c4_row9_col4, #T_6c4c4_row9_col5, #T_6c4c4_row10_col0, #T_6c4c4_row10_col2, #T_6c4c4_row10_col3, #T_6c4c4_row10_col4, #T_6c4c4_row10_col5, #T_6c4c4_row11_col0, #T_6c4c4_row11_col2, #T_6c4c4_row11_col3, #T_6c4c4_row11_col4, #T_6c4c4_row11_col5, #T_6c4c4_row12_col0, #T_6c4c4_row12_col2, #T_6c4c4_row12_col3, #T_6c4c4_row12_col4, #T_6c4c4_row12_col5, #T_6c4c4_row13_col0, #T_6c4c4_row13_col2, #T_6c4c4_row13_col3, #T_6c4c4_row13_col4, #T_6c4c4_row13_col5, #T_6c4c4_row14_col0, #T_6c4c4_row14_col2, #T_6c4c4_row14_col3, #T_6c4c4_row14_col4, #T_6c4c4_row14_col5, #T_6c4c4_row15_col0, #T_6c4c4_row15_col2, #T_6c4c4_row15_col3, #T_6c4c4_row15_col4, #T_6c4c4_row15_col5, #T_6c4c4_row16_col0, #T_6c4c4_row16_col2, #T_6c4c4_row16_col3, #T_6c4c4_row16_col4, #T_6c4c4_row16_col5, #T_6c4c4_row17_col0, #T_6c4c4_row17_col2, #T_6c4c4_row17_col3, #T_6c4c4_row17_col4, #T_6c4c4_row17_col5, #T_6c4c4_row18_col0, #T_6c4c4_row18_col2, #T_6c4c4_row18_col3, #T_6c4c4_row18_col4, #T_6c4c4_row18_col5, #T_6c4c4_row19_col0, #T_6c4c4_row19_col2, #T_6c4c4_row19_col3, #T_6c4c4_row19_col4, #T_6c4c4_row19_col5, #T_6c4c4_row20_col0, #T_6c4c4_row20_col2, #T_6c4c4_row20_col3, #T_6c4c4_row20_col4, #T_6c4c4_row20_col5 {
#   font-family: Segoe UI;
# }
# #T_6c4c4_row0_col1, #T_6c4c4_row1_col1, #T_6c4c4_row2_col1, #T_6c4c4_row3_col1, #T_6c4c4_row4_col1, #T_6c4c4_row5_col1, #T_6c4c4_row6_col1, #T_6c4c4_row7_col1, #T_6c4c4_row8_col1, #T_6c4c4_row9_col1, #T_6c4c4_row10_col1, #T_6c4c4_row11_col1, #T_6c4c4_row12_col1, #T_6c4c4_row13_col1, #T_6c4c4_row14_col1, #T_6c4c4_row15_col1, #T_6c4c4_row16_col1, #T_6c4c4_row17_col1, #T_6c4c4_row18_col1, #T_6c4c4_row19_col1, #T_6c4c4_row20_col1 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_6c4c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c4c4_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_6c4c4_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_6c4c4_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_6c4c4_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_6c4c4_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_6c4c4_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c4c4_level0_row0" class="row_heading level0 row0" >id</th>
#       <td id="T_6c4c4_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_6c4c4_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_6c4c4_row0_col2" class="data row0 col2" >99</td>
#       <td id="T_6c4c4_row0_col3" class="data row0 col3" >1000102.000000</td>
#       <td id="T_6c4c4_row0_col4" class="data row0 col4" >9900000190.000000</td>
#       <td id="T_6c4c4_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row1" class="row_heading level0 row1" >date</th>
#       <td id="T_6c4c4_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_6c4c4_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_6c4c4_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_6c4c4_row1_col3" class="data row1 col3" ></td>
#       <td id="T_6c4c4_row1_col4" class="data row1 col4" ></td>
#       <td id="T_6c4c4_row1_col5" class="data row1 col5" >Possible high cardinality column with 372 unique values: Use hash encoding or text embedding to reduce dimension.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row2" class="row_heading level0 row2" >price</th>
#       <td id="T_6c4c4_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_6c4c4_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_6c4c4_row2_col2" class="data row2 col2" >NA</td>
#       <td id="T_6c4c4_row2_col3" class="data row2 col3" >75000.000000</td>
#       <td id="T_6c4c4_row2_col4" class="data row2 col4" >7700000.000000</td>
#       <td id="T_6c4c4_row2_col5" class="data row2 col5" >Column has 1146 outliers greater than upper bound (1129575.00) or lower than lower bound(-162625.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row3" class="row_heading level0 row3" >bedrooms</th>
#       <td id="T_6c4c4_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_6c4c4_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_6c4c4_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_6c4c4_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_6c4c4_row3_col4" class="data row3 col4" >33.000000</td>
#       <td id="T_6c4c4_row3_col5" class="data row3 col5" >Column has 546 outliers greater than upper bound (5.50) or lower than lower bound(1.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row4" class="row_heading level0 row4" >bathrooms</th>
#       <td id="T_6c4c4_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_6c4c4_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_6c4c4_row4_col2" class="data row4 col2" >NA</td>
#       <td id="T_6c4c4_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_6c4c4_row4_col4" class="data row4 col4" >8.000000</td>
#       <td id="T_6c4c4_row4_col5" class="data row4 col5" >Column has 571 outliers greater than upper bound (3.62) or lower than lower bound(0.62). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row5" class="row_heading level0 row5" >sqft_living</th>
#       <td id="T_6c4c4_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_6c4c4_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_6c4c4_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_6c4c4_row5_col3" class="data row5 col3" >290.000000</td>
#       <td id="T_6c4c4_row5_col4" class="data row5 col4" >13540.000000</td>
#       <td id="T_6c4c4_row5_col5" class="data row5 col5" >Column has 572 outliers greater than upper bound (4234.50) or lower than lower bound(-257.50). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row6" class="row_heading level0 row6" >sqft_lot</th>
#       <td id="T_6c4c4_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_6c4c4_row6_col1" class="data row6 col1" >0.000000</td>
#       <td id="T_6c4c4_row6_col2" class="data row6 col2" >45</td>
#       <td id="T_6c4c4_row6_col3" class="data row6 col3" >520.000000</td>
#       <td id="T_6c4c4_row6_col4" class="data row6 col4" >1651359.000000</td>
#       <td id="T_6c4c4_row6_col5" class="data row6 col5" >Column has 2425 outliers greater than upper bound (19160.00) or lower than lower bound(-3432.00). Cap them or remove them.</td>
#     </tr>
#     <tr>
#       <th id="T_6c4c4_level0_row7" class="row_heading level0 row7" >floors</th>
#       <td id="T_6c4c4_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_6c4c4_row7_col1" class="data row7 col1" >0.000000</td>
#       <td id="T_6c4c4_row7_col2" class="data row7 col2" >NA</td>
#       <td id="T_6c4c4_row7_col3" class="data row7 c
# Number of All Scatter Plots = 15
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package omw-1.4 to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package omw-1.4 is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet2021 to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package wordnet2021 is already up-to-date!
# [nltk_data]    | Downloading package wordnet31 to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package wordnet31 is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# Could not draw wordcloud plot for date.
# Looks like you are missing some required data for this feature.
#
# To download the necessary data, simply run
#
#     python -m textblob.download_corpora
#
# or use the NLTK downloader to download the missing data: http://nltk.org/data.html
# If this doesn't fix the problem, file an issue at https://github.com/sloria/TextBlob/issues.
#
# All Plots done
# Time to run AutoViz = 6 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\tuomas.valtanen\AppData\Roaming\nltk_dat
# [nltk_data]    |     a...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular

# %% [markdown]
# ### You can also generate common charts with AutoViz

# %%
# to see the visualizations instead, try this
# remember to change the target variable based on your own dataset
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# depVar => dependent variable => target variable
report = AV.AutoViz("houses.csv", chart_format="bokeh", depVar="price")
# Out:
# Shape of your Data Set loaded: (21613, 21)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  4
#     Number of Integer-Categorical Columns =  13
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  1
#     Number of Discrete String Columns =  1
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  1
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     20 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
#
# ################ Regression problem #####################
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='282bda68-bb50-41fc-96b7-adda4ab7d6f1'>
#   <div id="bd2026d6-1e7a-4a16-aa7d-bf1d4e9acffb" data-root-id="282bda68-bb50-41fc-96b7-adda4ab7d6f1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"df114068-aad6-459b-a276-0242a585c325":{"version":"3.9.2","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"6fb8f512-71e7-42d1-bb07-7d99f66263d9","attributes":{"notifications":{"type":"object","name":"Notifications","id":"704c7061-d143-4457-bda9-fb9e5452e064"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"282bda68-bb50-41fc-96b7-adda4ab7d6f1"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"e91d52cd-37f7-4dcc-814f-3a83ba0548e1","attributes":{"plot_id":"282bda68-bb50-41fc-96b7-adda4ab7d6f1","comm_id":"168ee485754844e0a3e047ca49b01241","client_comm_id":"ca023c2203144008b6400e7c6e297a28"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"df114068-aad6-459b-a276-0242a585c325","roots":{"282bda68-bb50-41fc-96b7-adda4ab7d6f1":"bd2026d6-1e7a-4a16-aa7d-bf1d4e9acffb"},"root_ids":["282bda68-bb50-41fc-96b7-adda4ab7d6f1"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'8ac08a12-4b08-4230-927c-42ce6c5eac43': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'6d2173a3-f9a3-492b-b09f-31f16d1f8e14': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'61525189-4fc2-40b5-bd48-999cb79de412': {'version…
# BokehModel(combine_events=True, render_bundle={'docs_json': {'95056894-3b35-4b0e-9d80-53a53e9d1b71': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'4ff21896-88fa-4c8e-b939-4b72b74ca2e9': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'4094d4fb-3c9c-477a-9792-d8d36a892926': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'e1dcc9ac-3d41-4d44-a4db-281c86f9561a': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'86faf426-c69c-4217-8113-4f8a372eb59c': {'version…
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'11f3c666-8a5b-4d1a-80dd-151b2569f85d': {'version…
# Time to run AutoViz (in seconds) = 4
